# %%
import pandas as pd
import matplotlib.pylab as plt
from PIL import Image


# %matplotlib inline

# %%
root_dir = '/home/fedor/src/kaggle/cervix/'


df1 = pd.read_csv(root_dir + "type1.csv", header=None, names=['filename', 'cluster'])
df1['type'] = 1

df2 = pd.read_csv(root_dir + "type2.csv", header=None, names=['filename', 'cluster'])
df2['type'] = 2

df3 = pd.read_csv(root_dir + "type3.csv", header=None, names=['filename', 'cluster'])
df3['type'] = 3

df = pd.concat([df1,df2,df3]  )
df3.groupby(['type','cluster']).count()python dict to list
# Out:
#               filename
# type cluster
# 3    0               4
#      1              13
#      2              14
#      3              16
#      4              12
#      5              32
#      6              22
#      7              16
#      8              12
#      9              26
#      10             13
#      11              8
#      12             17
#      13             13
#      14             23
#      15             15
#      16             16
#      17             40
#      18             14
#      19              7
#      20             10
#      21              7
#      22             21
#      23              7
#      24             17
#      25             11
#      26              6
#      27             12
#      28              6
#      29             20

# %%
m = df1
fig = plt.figure(figsize=(20,20))
i = 1
for row in df3[df3.cluster == 6].itertuples():
    ax = fig.add_subplot(10,10,i)
    i+=1
    #im = Image.open(row.filename).convert('RGB')
    #ys = i*(image_size[0] + 2)*15
    #ye = min((i+1)*(image_size[0] + 2)*15, all_classes_images[class_index].shape[0])
    plt.imshow(plt.imread(row.filename))
    if i == 60:
        break
    #plt.title("Class %i, part %i" % (class_index, i))
